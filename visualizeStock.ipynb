# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore
#from datetime import timedelta
import seaborn
from matplotlib import pyplot as plt
import os

# %%
def drawChart(df : pd.DataFrame, stock_name : str):
    df['date'] = pd.to_datetime(df['date'])
    df.set_index(df['date'], inplace=True)
    plt.figure(figsize=(30, 10))
    plt.ylim(0, df['close'].max() * 1.1)
    plt.title(stock_name)
    plt.xlabel('Time')
    plt.ylabel('Price (VND)')
    seaborn.set_style('darkgrid')
    seaborn.lineplot(data = pd.DataFrame(df, columns=('date', 'close')))

# %%
# Get the current directory
current_directory = os.getcwd()

# Get all files in the current directory
files = os.listdir(current_directory)

# Filter CSV files
csv_files = [file for file in files if file.endswith('.csv')]

csv_files
# Out:
# ['myData_ACB_priceHistory_20240321.csv',
#  'myData_CTG_priceHistory_20240321.csv',
#  'myData_FPT_priceHistory_20240321.csv',
#  'myData_MBB_priceHistory_20240321.csv',
#  'myData_MWG_priceHistory_20240321.csv',
#  'myData_NVL_priceHistory_20240321.csv',
#  'myData_VNM_priceHistory_20240321.csv']

# %%
for file in csv_files:
    df = pd.read_csv(file)
    stock = file.split('_')[1]
    drawChart(df, stock_name=stock)
# Out:
# C:\Users\tranh\AppData\Local\Temp\ipykernel_14620\423929240.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# C:\Users\tranh\AppData\Local\Temp\ipykernel_14620\423929240.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# C:\Users\tranh\AppData\Local\Temp\ipykernel_14620\423929240.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# ...

# %%
df = pd.read_csv('myData_NVL_priceHistory_20240321.csv')
df
# Out:
#             date     open  highest   lowest    close  change  \
# 0     21/03/2024  16800.0  17100.0  16600.0  17100.0   550.0
# 1     20/03/2024  16500.0  16650.0  16350.0  16550.0    50.0
# 2     19/03/2024  16900.0  16900.0  16500.0  16500.0  -200.0
# 3     18/03/2024  16500.0  17100.0  16150.0  16700.0   200.0
# 4     15/03/2024  16450.0  16800.0  16400.0  16500.0    50.0
# ...          ...      ...      ...      ...      ...     ...
# 1825  10/01/2017  25139.0  25139.0  25012.0  25054.0   -85.0
# 1826  09/01/2017  25097.0  25182.0  24927.0  25182.0    85.0
# 1827  06/01/2017  25054.0  25139.0  24970.0  25139.0    85.0
# 1828  05/01/2017  25182.0  25224.0  25054.0  25097.0   -85.0
# 1829  04/01/2017  25054.0  25267.0  25054.0  25224.0   170.0
#
#       change_percentage    volume
# 0                  3.32  42479800
# 1                  0.30  12078500
# 2                 -1.20   9763100
# 3                  1.21  36466000
# 4                  0.30  19133900
# ...
